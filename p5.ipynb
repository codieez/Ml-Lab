# %% [markdown]
# # p5
# Python notebook starter.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
from collections import Counter
data=np.random.rand(100)
labels=['Class1' if x<=0.5 else 'Class2' for x in data[:50]]
def euclidein_dist(x1,x2):
    return abs(x1-x2)

def knn_classifier(train_data, train_labels, test_point,k):
    distances=[(euclidein_dist(test_point, train_data[i]),train_labels[i]) for i in range(len(train_data))]
    distances.sort(key=lambda x:x[0])
    k_nearest_neighbour=distances[:k]
    k_nearest_labels=[label for _,label in k_nearest_neighbour]
    return Counter(k_nearest_labels).most_common(1)[0][0]

train_data = data[:50]
train_labels = labels

test_data = data[50:]

k_values = [1, 2, 3, 4, 5, 20, 30]

results={}

for k in k_values:
    print(f'results for k = {k}:')
    classified_labels = [knn_classifier(train_data, train_labels, test_point, k) for test_point in test_data]
    results[k] = classified_labels

    for i, label in enumerate(classified_labels, start=51):
        print(f"Point x{i} (value: {test_data[i - 51]:.4f}) is classified as {label}")
    print("\n")

print("Classification complete.\n")

for k in k_values:
    classified_labels = results[k]
    class1_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class1"]
    class2_points = [test_data[i] for i in range(len(test_data)) if classified_labels[i] == "Class2"]

    plt.figure(figsize=(10, 6))
    plt.scatter(train_data, [0] * len(train_data), c=["blue" if label == "Class1" else "red" for label in train_labels],
                label="Training Data", marker="o")
    plt.scatter(class1_points, [1] * len(class1_points), c="blue", label="Class1 (Test)", marker="x")
    plt.scatter(class2_points, [1] * len(class2_points), c="red", label="Class2 (Test)", marker="x")

    plt.title(f"k-NN Classification Results for k = {k}")
    plt.xlabel("Data Points")
    plt.ylabel("Classification Level")
    plt.legend()
    plt.grid(True)
    plt.show()
# Out:
# results for k = 1:
# Point x51 (value: 0.6448) is classified as Class2
# Point x52 (value: 0.9367) is classified as Class2
# Point x53 (value: 0.1214) is classified as Class1
# Point x54 (value: 0.3641) is classified as Class1
# Point x55 (value: 0.6281) is classified as Class2
# Point x56 (value: 0.1689) is classified as Class1
# Point x57 (value: 0.1018) is classified as Class1
# Point x58 (value: 0.4855) is classified as Class1
# Point x59 (value: 0.7838) is classified as Class2
# Point x60 (value: 0.8019) is classified as Class2
# Point x61 (value: 0.9423) is classified as Class2
# Point x62 (value: 0.2380) is classified as Class1
# Point x63 (value: 0.5420) is classified as Class2
# Point x64 (value: 0.4106) is classified as Class1
# Point x65 (value: 0.6131) is classified as Class2
# Point x66 (value: 0.5203) is classified as Class2
# Point x67 (value: 0.9660) is classified as Class2
# Point x68 (value: 0.0370) is classified as Class1
# Point x69 (value: 0.2463) is classified as Class1
# Point x70 (value: 0.2743) is classified as Class1
# Point x71 (value: 0.5932) is classified as Class2
# Point x72 (value: 0.6195) is classified as Class2
# Point x73 (value: 0.2021) is classified as Class1
# Point x74 (value: 0.8586) is classified as Class2
# Point x75 (value: 0.7392) is classified as Class2
# Point x76 (value: 0.5027) is classified as Class2
# Point x77 (value: 0.8198) is classified as Class2
# Point x78 (value: 0.2082) is classified as Class1
# Point x79 (value: 0.7194) is classified as Class2
# Point x80 (value: 0.1996) is classified as Class1
# Point x81 (value: 0.8146) is classified as Class2
# Point x82 (value: 0.2987) is classified as Class1
# Point x83 (value: 0.8698) is classified as Class2
# Point x84 (value: 0.4931) is classified as Class2
# Point x85 (value: 0.5667) is classified as Class2
# Point x86 (value: 0.9031) is classified as Class2
# Point x87 (value: 0.1803) is classified as Class1
# Point x88 (value: 0.5157) is classified as Class2
# Point x89 (value: 0.7154) is classified as Class2
# Point x90 (value: 0.1359) is classified as Class1
# Point x91 (value: 0.9810) is classified as Class2
# Point x92 (value: 0.9218) is classified as Class2
# Point x93 (value: 0.8917) is classified as Class2
# Point x94 (value: 0.4188) is classified as Class1
# Point x95 (value: 0.9385) is classified as Class2
# Point x96 (value: 0.8509) is classified as Class2
# Point x97 (value: 0.6769) is classified as Class2
# Point x98 (value: 0.3717) is classified as Class1
# Point x99 (value: 0.1108) is classified as Class1
# Point x100 (value: 0.3961) is classified as Class1
#
#
# results for k = 2:
# Point x51 (value: 0.6448) is classified as Class2
# Point x52 (value: 0.9367) is classified as Class2
# Point x53 (value: 0.1214) is classified as Class1
# Point x54 (value: 0.3641) is classified as Class1
# Point x55 (value: 0.6281) is classified as Class2
# Point x56 (value: 0.1689) is classified as Class1
# Point x57 (value: 0.1018) is classified as Class1
# Point x58 (value: 0.4855) is classified as Class1
# Point x59 (value: 0.7838) is classified as Class2
# Point x60 (value: 0.8019) is classified as Class2
# Point x61 (value: 0.9423) is classified as Class2
# Point x62 (value: 0.2380) is classified as Class1
# Point x63 (value: 0.5420) is classified as Class2
# Point x64 (value: 0.4106) is classified as Class1
# Point x65 (value: 0.6131) is classified as Class2
# Point x66 (value: 0.5203) is classified as Class2
# Point x67 (value: 0.9660) is classified as Class2
# Point x68 (value: 0.0370) is classified as Class1
# Point x69 (value: 0.2463) is classified as Class1
# Point x70 (value: 0.2743) is classified as Class1
# Point x71 (value: 0.5932) is classified as Class2
# Point x72 (value: 0.6195) is classified as Class2
# Point x73 (value: 0.2021) is classified as Class1
# Point x74 (value: 0.8586) is classified as Class2
# Point x75 (value: 0.7392) is classified as Class2
# Point x76 (value: 0.5027) is classified as Class2
# Point x77 (value: 0.8198) is classified as Class2
# Point x78 (value: 0.2082) is classified as Class1
# Point x79 (value: 0.7194) is classified as Class2
# Point x80 (value: 0.1996) is classified as Class1
# Point x81 (value: 0.8146) is classified as Class2
# Point x82 (value: 0.2987) is classified as Class1
# Point x83 (value: 0.8698) is classified as Class2
# Point x84 (value: 0.4931) is classified as Class2
# Point x85 (value: 0.5667) is classified as Class2
# Point x86 (value: 0.9031) is classified as Class2
# Point x87 (value: 0.1803) is classified as Class1
# Point x88 (value: 0.5157) is classified as Class2
# Point x89 (value: 0.7154) is classified as Class2
# Point x90 (value: 0.1359) is classified as Class1
# Point x91 (value: 0.9810) is classified as Class2
# Point x92 (value: 0.9218) is classified as Class2
# Point x93 (value: 0.8917) is classified as Class2
# Point x94 (value: 0.4188) is classified as Class1
# Point x95 (value: 0.9385) is classified as Class2
# Point x96 (value: 0.8509) is classified as Class2
# Point x97 (value: 0.6769) is classified as Class2
# Point x98 (value: 0.3717) is classified as Class1
# Point x99 (value: 0.1108) is classified as Class1
# Point x100 (value: 0.3961) is classified as Class1
#
#
# results for k = 3:
# Point x51 (value: 0.6448) is classified as Class2
# Point x52 (value: 0.9367) is classified as Class2
# Point x53 (value: 0.1214) is classified as Class1
# Point x54 (value: 0.3641) is classified as Class1
# Point x55 (value: 0.6281) is classified as Class2
# Point x56 (value: 0.1689) is classified as Class1
# Point x57 (value: 0.1018) is classified as Class1
# Point x58 (value: 0.4855) is classified as Class2
# Point x59 (value: 0.7838) is classified as Class2
# Point x60 (value: 0.8019) is classified as Class2
# Point x61 (value: 0.9423) is classified as Class2
# Point x62 (value: 0.2380) is classified as Class1
# Point x63 (value: 0.5420) is classified as Class2
# Point x64 (value: 0.4106) is classified as Class1
# Point x65 (value: 0.6131) is classified as Class2
# Point x66 (value: 0.5203) is classified as Class2
# Point x67 (value: 0.9660) is classified as Class2
# Point x68 (value: 0.0370) is classified as Class1
# Point x69 (value: 0.2463) is classified as Class1
# Point x70 (value: 0.2743) is classified as Class1
# Point x71 (value: 0.5932) is classified as Class2
# Point x72 (value: 0.6195) is classified as Class2
# Point x73 (value: 0.2021) is classified as Class1
# Point x74 (value: 0.8586) is classified as Class2
# Point x75 (value: 0.7392) is classified as Class2
# Point x76 (value: 0.5027) is classified as Class2
# Point x77 (value: 0.8198) is classified as Class2
# Point x78 (value: 0.2082) is classified as Class1
# Point x79 (value: 0.7194) is classified as Class2
# Point x80 (value: 0.1996) is classified as Class1
# Point x81 (value: 0.8146) is classified as Class2
# Point x82 (value: 0.2987) is classified as Class1
# Point x83 (value: 0.8698) is classified as Class2
# Point x84 (value: 0.4931) is classified as Class2
# Point x85 (value: 0.5667) is classified as Class2
# Point x86 (value: 0.9031) is classified as Class2
# Point x87 (value: 0.1803) is classified as Class1
# Point x88 (value: 0.5157) is classified as Class2
# Point x89 (value: 0.7154) is classified as Class2
# Point x90 (value: 0.1359) is classified as Class1
# Point x91 (value: 0.9810) is classified as Class2
# Point x92 (value: 0.9218) is classified as Class2
# Point x93 (value: 0.8917) is classified as Class2
# Point x94 (value: 0.4188) is classified as Class1
# Point x95 (value: 0.9385) is classified as Class2
# Point x96 (value: 0.8509) is classified as Class2
# Point x97 (value: 0.6769) is classified as Class2
# Point x98 (value: 0.3717) is classified as Class1
# Point x99 (value: 0.1108) is classified as Class1
# Point x100 (value: 0.3961) is classified as Class1
#
#
# results for k = 4:
# Point x51 (value: 0.6448) is classified as Class2
# Point x52 (value: 0.9367) is classified as Class2
# Point x53 (value: 0.1214) is classified as Class1
# Point x54 (value: 0.3641) is classified as Class1
# Point x55 (value: 0.6281) is classified as Class2
# Point x56 (value: 0.1689) is classified as Class1
# Point x57 (value: 0.1018) is classified as Class1
# Point x58 (value: 0.4855) is classified as Class2
# Point x59 (value: 0.7838) is classified as Class2
# Point x60 (value: 0.8019) is classified as Class2
# Point x61 (value: 0.9423) is classified as Class2
# Point x62 (value: 0.2380) is classified as Class1
# Point x63 (value: 0.5420) is classified as Class2
# Point x64 (value: 0.4106) is classified as Class1
# Point x65 (value: 0.6131) is classified as Class2
# Point x66 (value: 0.5203) is classified as Class2
# Point x67 (value: 0.9660) is classified as Class2
# Point x68 (value: 0.0370) is classified as Class1
# Point x69 (value: 0.2463) is classified as Class1
# Point x70 (value: 0.2743) is classified as Class1
# Point x71 (value: 0.5932) is classified as Class2
# Point x72 (value: 0.6195) is classified as Class2
# Point x73 (value: 0.2021) is classified as Class1
# Point x74 (value: 0.8586) is classified as Class2
# Point x75 (value: 0.7392) is classified as Class2
# Point x76 (value: 0.5027) is classified as Class2
# Point x77 (value: 0.8198) is classified as Class2
# Point x78 (value: 0.2082) is classified as Class1
# Point x79 (value: 0.7194) is classified as Class2
# Point x80 (value: 0.1996) is classified as Class1
# Point x81 (value: 0.8146) is classified as Class2
# Point x82 (value: 0.2987) is classified as Class1
# Point x83 (value: 0.8698) is classified as Class2
# Point x84 (value: 0.4931) is classified as Class2
# Point x85 (value: 0.5667) is classified as Class2
# Point x86 (value: 0.9031) is classified as Class2
# Point x87 (value: 0.1803) is classified as Class1
# Point x88 (value: 0.5157) is classified as Class2
# Point x89 (value: 0.7154) is classified as Class2
# Point x90 (value: 0.1359) is classified as Class1
# Point x91 (value: 0.9810) is classified as Class2
# Point x92 (value: 0.9218) is classified as Class2
# Point x93 (value: 0.8917) is classified as Class2
# Point x94 (value: 0.4188) is classified as Class1
# Point x95 (value: 0.9385) is classified as Class2
# Point x96 (value: 0.8509) is classified as Class2
# Point x97 (value: 0.6769) is classified as Class2
# Point x98 (value: 0.3717) is classified as Class1
# Point x99 (value: 0.1108) is classified as Class1
# Point x100 (value: 0.3961) is classified as Class1
#
#
# results for k = 5:
# Point x51 (value: 0.6448) is classified as Class2
# Point x52 (value: 0.9367) is classified as Class2
# Point x53 (value: 0.1214) is classified as Class1
# Point x54 (value: 0.3641) is classified as Class1
# Point x55 (value: 0.6281) is classified as Class2
# Point x56 (value: 0.1689) is classified as Class1
# Point x57 (value: 0.1018) is classified as Class1
# Point x58 (value: 0.4855) is classified as Class2
# Point x59 (value: 0.7838) is classified as Class2
# Point x60 (value: 0.8019) is classified as Class2
# Point x61 (value: 0.9423) is classified as Class2
# Point x62 (value: 0.2380) is classified as Class1
# Point x63 (value: 0.5420) is classified as Class2
# Point x64 (value: 0.4106) is classified as Class1
# Point x65 (value: 0.6131) is classified as Class2
# Point x66 (value: 0.5203) is classified as Class2
# Point x67 (value: 0.9660) is classified as Class2
# Point x68 (value: 0.0370) is classified as Class1
# Point x69 (value: 0.2463) is classified as Class1
# Point x70 (value: 0.2743) is classified as Class1
# Point x71 (value: 0.5932) is classified as Class2
# Point x72 (value: 0.6195) is classified as Class2
# Point x73 (value: 0.2021) is classified as Class1
# Point x74 (value: 0.8586) is classified as Class2
# Point x75 (value: 0.7392) is classified as Class2
# Point x76 (value: 0.5027) is classified as Class2
# Point x77 (value: 0.8198) is classified as Class2
# Point x78 (value: 0.2082) is classified as Class1
# Point x79 (value: 0.7194) is classified as Class2
# Point x80 (value: 0.1996) is classified as Class1
# Point x81 (value: 0.8146) is classified as Class2
# Point x82 (value: 0.2987) is classified as Class1
# Point x83 (value: 0.8698) is classified as Class2
# Point x84 (value: 0.4931) is classified as Class2
# Point x85 (value: 0.5667) is classified as Class2
# Point x86 (value: 0.9031) is classified as Class2
# Point x87 (value: 0.1803) is classified as Class1
# Point x88 (value: 0.5157) is classified as Class2
# Point x89 (value: 0.7154) is classified as Class2
# Point x90 (value: 0.1359) is classified as Class1
# Point x91 (value: 0.9810) is classified as Class2
# Point x92 (value: 0.9218) is classified as Class2
# Point x93 (value: 0.8917) is classified as Class2
# Point x94 (value: 0.4188) is classified as Class1
# Point x95 (value: 0.9385) is classified as Class2
# Point x96 (value: 0.8509) is classified as Class2
# Point x97 (value: 0.6769) is classified as Class2
# Point x98 (value: 0.3717) is classified as Class1
# Point x99 (value: 0.1108) is classified as Class1
# Point x100 (value: 0.3961) is classified as Class1
#
#
# results for k = 20:
# Point x51 (value: 0.6448) is classified as Class2
# Point x52 (value: 0.9367) is classified as Class2
# Point x53 (value: 0.1214) is classified as Class1
# Point x54 (value: 0.3641) is classified as Class1
# Point x55 (value: 0.6281) is classified as Class2
# Point x56 (value: 0.1689) is classified as Class1
# Point x57 (value: 0.1018) is classified as Class1
# Point x58 (value: 0.4855) is classified as Class1
# Point x59 (value: 0.7838) is classified as Class2
# Point x60 (value: 0.8019) is classified as Class2
# Point x61 (value: 0.9423) is classified as Class2
# Point x62 (value: 0.2380) is classified as Class1
# Point x63 (value: 0.5420) is classified as Class2
# Point x64 (value: 0.4106) is classified as Class1
# Point x65 (value: 0.6131) is classified as Class2
# Point x66 (value: 0.5203) is classified as Class2
# Point x67 (value: 0.9660) is classified as Class2
# Point x68 (value: 0.0370) is classified as Class1
# Point x69 (value: 0.2463) is classified as Class1
# Point x70 (value: 0.2743) is classified as Class1
# Point x71 (value: 0.5932) is classified as Class2
# Point x72 (value: 0.6195) is classified as Class2
# Point x73 (value: 0.2021) is classified as Class1
# Point x74 (value: 0.8586) is classified as Class2
# Point x75 (value: 0.7392) is classified as Class2
# Point x76 (value: 0.5027) is classified as Class2
# Point x77 (value: 0.8198) is classified as Class2
# Point x78 (value: 0.2082) is classified as Class1
# Point x79 (value: 0.7194) is classified as Class2
# Point x80 (value: 0.1996) is classified as Class1
# Point x81 (value: 0.8146) is classified as Class2
# Point x82 (value: 0.2987) is classified as Class1
# Point x83 (value: 0.8698) is classified as Class2
# Point x84 (value: 0.4931) is classified as Class2
# Point x85 (value: 0.5667) is classified as Class2
# Point x86 (value: 0.9031) is classified as Class2
# Point x87 (value: 0.1803) is classified as Class1
# Point x88 (value: 0.5157) is classified as Class2
# Point x89 (value: 0.7154) is classified as Class2
# Point x90 (value: 0.1359) is classified as Class1
# Point x91 (value: 0.9810) is classified as Class2
# Point x92 (value: 0.9218) is classified as Class2
# Point x93 (value: 0.8917) is classified as Class2
# Point x94 (value: 0.4188) is classified as Class1
# Point x95 (value: 0.9385) is classified as Class2
# Point x96 (value: 0.8509) is classified as Class2
# Point x97 (value: 0.6769) is classified as Class2
# Point x98 (value: 0.3717) is classified as Class1
# Point x99 (value: 0.1108) is classified as Class1
# Point x100 (value: 0.3961) is classified as Class1
#
#
# results for k = 30:
# Point x51 (value: 0.6448) is classified as Class2
# Point x52 (value: 0.9367) is classified as Class2
# Point x53 (value: 0.1214) is classified as Class1
# Point x54 (value: 0.3641) is classified as Class1
# Point x55 (value: 0.6281) is classified as Class2
# Point x56 (value: 0.1689) is classified as Class1
# Point x57 (value: 0.1018) is classified as Class1
# Point x58 (value: 0.4855) is classified as Class1
# Point x59 (value: 0.7838) is classified as Class2
# Point x60 (value: 0.8019) is classified as Class2
# Point x61 (value: 0.9423) is classified as Class2
# Point x62 (value: 0.2380) is classified as Class1
# Point x63 (value: 0.5420) is classified as Class2
# Point x64 (value: 0.4106) is classified as Class1
# Point x65 (value: 0.6131) is classified as Class2
# Point x66 (value: 0.5203) is classified as Class2
# Point x67 (value: 0.9660) is classified as Class2
# Point x68 (value: 0.0370) is classified as Class1
# Point x69 (value: 0.2463) is classified as Class1
# Point x70 (value: 0.2743) is classified as Class1
# Point x71 (value: 0.5932) is classified as Class2
# Point x72 (value: 0.6195) is classified as Class2
# Point x73 (value: 0.2021) is classified as Class1
# Point x74 (value: 0.8586) is classified as Class2
# Point x75 (value: 0.7392) is classified as Class2
# Point x76 (value: 0.5027) is classified as Class2
# Point x77 (value: 0.8198) is classified as Class2
# Point x78 (value: 0.2082) is classified as Class1
# Point x79 (value: 0.7194) is classified as Class2
# Point x80 (value: 0.1996) is classified as Class1
# Point x81 (value: 0.8146) is classified as Class2
# Point x82 (value: 0.2987) is classified as Class1
# Point x83 (value: 0.8698) is classified as Class2
# Point x84 (value: 0.4931) is classified as Class2
# Point x85 (value: 0.5667) is classified as Class2
# Point x86 (value: 0.9031) is classified as Class2
# Point x87 (value: 0.1803) is classified as Class1
# Point x88 (value: 0.5157) is classified as Class2
# Point x89 (value: 0.7154) is classified as Class2
# Point x90 (value: 0.1359) is classified as Class1
# Point x91 (value: 0.9810) is classified as Class2
# Point x92 (value: 0.9218) is classified as Class2
# Point x93 (value: 0.8917) is classified as Class2
# Point x94 (value: 0.4188) is classified as Class1
# Point x95 (value: 0.9385) is classified as Class2
# Point x96 (value: 0.8509) is classified as Class2
# Point x97 (value: 0.6769) is classified as Class2
# Point x98 (value: 0.3717) is classified as Class1
# Point x99 (value: 0.1108) is classified as Class1
# Point x100 (value: 0.3961) is classified as Class1
#
#
# Classification complete.

# %%
# !pip install numpy
# !pip install matplotlib
# Out:
# Requirement already satisfied: numpy in /usr/local/python/3.12.1/lib/python3.12/site-packages (2.4.6)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /usr/local/python/3.12.1/lib/python3.12/site-packages (3.10.9)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (2.4.6)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/codespace/.local/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
